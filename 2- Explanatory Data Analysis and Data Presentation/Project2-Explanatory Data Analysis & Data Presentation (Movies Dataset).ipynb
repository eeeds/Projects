# %% [markdown]
# # Project 2: Explanatory Data Analysis & Data Presentation (Movies Dataset)

# %% [markdown]
# ## Data Import and first Inspection

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

pd.options.display.max_columns = 30
pd.options.display.float_format='{:.2f}'.format

df = pd.read_csv('datasets/movies_complete.csv', parse_dates = ['release_date'])

df.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                      genres           belongs_to_collection original_language  \
# 0   Animation|Comedy|Family            Toy Story Collection                en
# 1  Adventure|Fantasy|Family                             NaN                en
# 2            Romance|Comedy       Grumpy Old Men Collection                en
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   tagline                20284 non-null  object
#  3   release_date           44657 non-null  datetime64[ns]
#  4   genres                 42586 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44681 non-null  object
#  7   budget_musd            8854 non-null   float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38835 non-null  object
#  11  vote_count             44691 non-null  float64
#  12  vote_average           42077 non-null  float64
#  13  popularity             44691 non-null  float64
# ...

# %%
df.describe()
# Out:
#              id  budget_musd  revenue_musd  vote_count  vote_average  \
# count  44691.00      8854.00       7385.00    44691.00      42077.00
# mean  107186.24        21.67         68.97      111.65          6.00
# std   111806.36        34.36        146.61      495.32          1.28
# min        2.00         0.00          0.00        0.00          0.00
# 25%    26033.50         2.00          2.41        3.00          5.30
# 50%    59110.00         8.20         16.87       10.00          6.10
# 75%   154251.00        25.00         67.64       35.00          6.80
# max   469172.00       380.00       2787.97    14075.00         10.00
#
#        popularity  runtime  cast_size  crew_size
# count    44691.00 43179.00   44691.00   44691.00
# mean         2.96    97.57      12.48      10.31
# std          6.04    34.65      12.12      15.89
# min          0.00     1.00       0.00       0.00
# 25%          0.40    86.00       6.00       2.00
# ...

# %%
df.hist(figsize = (20,12), bins = 100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A537290348>,
# ...
#       dtype=object)

# %%
df.vote_average.value_counts(dropna = False)
# Out:
# NaN     2614
# 6.00    2421
# 5.00    1969
# 7.00    1859
# 6.50    1705
#         ...
# 9.40       3
# 1.10       1
# 9.80       1
# 0.70       1
# 9.60       1
# Name: vote_average, Length: 93, dtype: int64

# %%
df.vote_count.value_counts(dropna = False)
# Out:
# 1.00       3186
# 2.00       3056
# 3.00       2729
# 0.00       2614
# 4.00       2442
#            ...
# 838.00        1
# 1432.00       1
# 1825.00       1
# 4110.00       1
# 992.00        1
# Name: vote_count, Length: 1820, dtype: int64

# %%
df.describe ( include = 'object')
# Out:
#              title                 tagline genres belongs_to_collection  \
# count        44691                   20284  42586                  4463
# unique       41605                   20171   4044                  1691
# top     Cinderella  Based on a true story.  Drama       The Bowery Boys
# freq            11                       7   4935                    29
#
#        original_language       production_companies      production_countries  \
# count              44681                      33356                     38835
# unique                89                      22537                      2377
# top                   en  Metro-Goldwyn-Mayer (MGM)  United States of America
# freq               31755                        741                     17723
#
#                                     overview spoken_languages  \
# count                                  43740            41094
# unique                                 43715             1828
# ...

# %%
df[df.title == 'Cinderella']
# Out:
#            id       title                             tagline release_date  \
# 984     11224  Cinderella  The greatest love story ever told.   1950-03-04
# 12988   42884  Cinderella                                 NaN   1997-11-02
# 23254   92349  Cinderella                                 NaN   1914-12-28
# 23265  105875  Cinderella          The version children love!   2002-08-06
# 28073  261985  Cinderella                                 NaN   2011-10-30
# 28340  150689  Cinderella     Midnight is just the beginning.   2015-03-12
# 33805   42651  Cinderella                                 NaN   1947-11-28
# 35114   44459  Cinderella                                 NaN   1957-03-31
# 35116  289673  Cinderella                                 NaN   2000-01-01
# 40439  114108  Cinderella                                 NaN   1899-10-01
# 44633   98604  Cinderella                                 NaN   2012-02-14
#
# ...

# %% [markdown]
# __Some additional information on Features/Columns__:

# %% [markdown]
# * **id:** The ID of the movie (clear/unique identifier).
# * **title:** The Official Title of the movie.
# * **tagline:** The tagline of the movie.
# * **release_date:** Theatrical Release Date of the movie.
# * **genres:** Genres associated with the movie.
# * **belongs_to_collection:** Gives information on the movie series/franchise the particular film belongs to.
# * **original_language:** The language in which the movie was originally shot in.
# * **budget_musd:** The budget of the movie in million dollars.
# * **revenue_musd:** The total revenue of the movie in million dollars.
# * **production_companies:** Production companies involved with the making of the movie.
# * **production_countries:** Countries where the movie was shot/produced in.
# * **vote_count:** The number of votes by users, as counted by TMDB.
# * **vote_average:** The average rating of the movie.
# * **popularity:** The Popularity Score assigned by TMDB.
# * **runtime:** The runtime of the movie in minutes.
# * **overview:** A brief blurb of the movie.
# * **spoken_languages:** Spoken languages in the film.
# * **poster_path:** The URL of the poster image.
# * **cast:** (Main) Actors appearing in the movie.
# * **cast_size:** number of Actors appearing in the movie.
# * **director:** Director of the movie.
# * **crew_size:** Size of the film crew (incl. director, excl. actors).

# %% [markdown]
# ## The best and the worst movies...

# %% [markdown]
# 2. __Filter__ the Dataset and __find the best/worst n Movies__ with the

# %% [markdown]
# - Highest Revenue
# - Highest Budget
# - Highest Profit (=Revenue - Budget)
# - Lowest Profit (=Revenue - Budget)
# - Highest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Lowest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Highest number of Votes
# - Highest Rating (only movies with 10 or more Ratings)
# - Lowest Rating (only movies with 10 or more Ratings)
# - Highest Popularity

# %% [markdown]
# __Define__ an appropriate __user-defined function__ to reuse code.

# %% [markdown]
# __Movies Top 5 - Highest Revenue__

# %%
df.sort_values(by =['revenue_musd'], ascending = False, inplace = False, na_position = 'last').head(5)
# Out:
#            id                         title  \
# 14448   19995                        Avatar
# 26265  140607  Star Wars: The Force Awakens
# 1620      597                       Titanic
# 17669   24428                  The Avengers
# 24812  135397                Jurassic World
#
#                                          tagline release_date  \
# 14448                Enter the World of Pandora.   2009-12-10
# 26265              Every generation has a story.   2015-12-15
# 1620   Nothing on Earth could come between them.   1997-11-18
# 17669                    Some assembly required.   2012-04-25
# 24812                          The park is open.   2015-06-09
#
#                                           genres     belongs_to_collection  \
# 14448   Action|Adventure|Fantasy|Science Fiction         Avatar Collection
# 26265   Action|Adventure|Science Fiction|Fantasy      Star Wars Collection
# 1620                      Drama|Romance|Thriller                       NaN
# ...

# %% [markdown]
# __Movies Top 5 - Highest Budget__

# %%
df.sort_values(by =['budget_musd'], ascending = False, inplace = False, na_position = 'last').head(5)
# Out:
#           id                                        title  \
# 16986   1865  Pirates of the Caribbean: On Stranger Tides
# 11743    285     Pirates of the Caribbean: At World's End
# 26268  99861                      Avengers: Age of Ultron
# 10985   1452                             Superman Returns
# 18517  49529                                  John Carter
#
#                                               tagline release_date  \
# 16986                     Live Forever Or Die Trying.   2011-05-14
# 11743  At the end of the world, the adventure begins.   2007-05-19
# 26268                             A New Age Has Come.   2015-04-22
# 10985                                             NaN   2006-06-28
# 18517            Lost in our world, found in another.   2012-03-07
#
#                                          genres  \
# 16986                  Adventure|Action|Fantasy
# 11743                  Adventure|Fantasy|Action
# 26268          Action|Adventure|Science Fiction
# ...

# %% [markdown]
# __Movies Top 5 - Highest Profit__

# %%
df['Profit'] = df['revenue_musd'] - df['budget_musd']
df.sort_values( by = ['Profit'], ascending = False, inplace = False, na_position= 'last').head(5)
# Out:
#            id                         title  \
# 14448   19995                        Avatar
# 26265  140607  Star Wars: The Force Awakens
# 1620      597                       Titanic
# 24812  135397                Jurassic World
# 28501  168259                     Furious 7
#
#                                          tagline release_date  \
# 14448                Enter the World of Pandora.   2009-12-10
# 26265              Every generation has a story.   2015-12-15
# 1620   Nothing on Earth could come between them.   1997-11-18
# 24812                          The park is open.   2015-06-09
# 28501                        Vengeance Hits Home   2015-04-01
#
#                                           genres  \
# 14448   Action|Adventure|Fantasy|Science Fiction
# 26265   Action|Adventure|Science Fiction|Fantasy
# 1620                      Drama|Romance|Thriller
# 24812  Action|Adventure|Science Fiction|Thriller
# 28501                                     Action
#
# ...

# %% [markdown]
# __Movies Top 5 - Lowest Profit__

# %%
df.sort_values( by = ['Profit'], ascending = True, inplace = False, na_position= 'last').head(5)
# Out:
#            id                                        title  \
# 20959   57201                              The Lone Ranger
# 7164    10733                                    The Alamo
# 16659   50321                              Mars Needs Moms
# 43611  339964  Valerian and the City of a Thousand Planets
# 2684     1911                             The 13th Warrior
#
#                          tagline release_date  \
# 20959    Never Take Off the Mask   2013-07-03
# 7164       You will never forget   2004-04-07
# 16659  Mom needs a little space.   2011-03-09
# 43611                        NaN   2017-07-20
# 2684        Prey for the living.   1999-08-27
#
#                                  genres belongs_to_collection  \
# 20959          Action|Adventure|Western                   NaN
# 7164                Western|History|War                   NaN
# 16659        Adventure|Animation|Family                   NaN
# 43611  Adventure|Science Fiction|Action                   NaN
# ...

# %% [markdown]
# __Movies Top 5 - Highest ROI__

# %%
df_copy = df[df['budget_musd']>=10]

df_copy['Highest ROI'] = df_copy['revenue_musd']/df_copy['budget_musd']

df_copy.sort_values(by = ['Highest ROI'], ascending = False).head(5)
# Out:
# c:\users\encin\anaconda3\envs\mopc\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#           id                       title  \
# 1055     601  E.T. the Extra-Terrestrial
# 255       11                   Star Wars
# 588      114                Pretty Woman
# 18300  77338            The Intouchables
# 1144    1891     The Empire Strikes Back
#
#                                                  tagline release_date  \
# 1055   He is afraid. He is alone. He is three million...   1982-04-03
# 255         A long time ago in a galaxy far, far away...   1977-05-25
# ...

# %% [markdown]
# __Movies Top 5 - Lowest ROI__

# %%
df_copy.sort_values(by = ['Highest ROI'], ascending = True).head(5)
# Out:
#           id            title  \
# 6955   14844  Chasing Liberty
# 8041   18475      The Cookout
# 17381  33927         Deadfall
# 6678   10944       In the Cut
# 20015  98339    The Samaritan
#
#                                                  tagline release_date  \
# 6955   How do you fall in love with the whole world w...   2004-01-09
# 8041                     This summer, get your grill on!   2004-09-03
# 17381                                ...The ultimate con   1993-10-08
# 6678     Everything you know about desire is dead wrong.   2003-09-09
# 20015                                                NaN   2012-03-02
#
#                      genres belongs_to_collection original_language  \
# 6955         Comedy|Romance                   NaN                en
# 8041           Comedy|Drama                   NaN                en
# 17381  Crime|Drama|Thriller                   NaN                en
# 6678       Mystery|Thriller                   NaN                en
# ...

# %% [markdown]
# __Movies Top 5 - Most Votes__

# %%
df.sort_values(by = ['vote_count'], ascending = False)[['title', 'vote_count']].head(5)
# Out:
#                  title  vote_count
# 15368        Inception    14075.00
# 12396  The Dark Knight    12269.00
# 14448           Avatar    12114.00
# 17669     The Avengers    12000.00
# 26272         Deadpool    11444.00

# %% [markdown]
# __Movies Top 5 - Highest Rating__

# %%
df[df['vote_count']>=10].sort_values(by = ['vote_average'], ascending = False)[['title', 'vote_average']].head(5)
# Out:
#                                                    title  vote_average
# 20787  As I Was Moving Ahead Occasionally I Saw Brief...          9.50
# 42626                                    Planet Earth II          9.50
# 18462                                      The Civil War          9.20
# 10233                        Dilwale Dulhania Le Jayenge          9.10
# 42822                                             Cosmos          9.10

# %% [markdown]
# __Movies Top 5 - Lowest Rating__

# %%
df[df['vote_count']>=10].sort_values(by = ['vote_average'], ascending = True)[['title', 'vote_average']].head(5)
# Out:
#                                  title  vote_average
# 41602             Call Me by Your Name          0.00
# 30618   Extinction: Nature Has Evolved          0.00
# 43576  How to Talk to Girls at Parties          0.00
# 25418                      Santa Claus          1.60
# 7030          The Beast of Yucca Flats          1.60

# %% [markdown]
# __Movies Top 5 - Most Popular__

# %%
df.sort_values(by = ['popularity'], ascending = False)[['title', 'popularity']].head(5)
# Out:
#                       title  popularity
# 30330               Minions      547.49
# 32927          Wonder Woman      294.34
# 41556  Beauty and the Beast      287.25
# 42940           Baby Driver      228.03
# 24187            Big Hero 6      213.85

# %%
#We can do this in one function
def best_worst(n, by, ascending = False, min_bud = 0, min_votes = 0):
    df2 = df_best.loc[(df_best.Budget>=min_bud)&(df_best.Votes>=min_votes),
                         ["", by]].sort_values(by = by, ascending = ascending).head(n).copy()
    return HTML(df2.to_html(escape = False))

#Preprocessing the data for this function

df_best = df[['poster_path', 'title', 'budget_musd', 'revenue_musd', 'vote_count', 
             'vote_average', 'popularity']].copy()
df_best['profit_musd'] = df.revenue_musd.sub(df.budget_musd)
df_best['return'] = df.revenue_musd.div(df.budget_musd)
#Defining columns names
df_best.columns = ["", 'Title', 'Budget', 'Revenue', 'Votes', 'Average Rating', 'Popularity', 'Profit', 'ROI']
df_best.set_index('Title', inplace = True)

# %%
from IPython.display import HTML
#Hightest Revenue
best_worst(n = 5, by = 'Revenue' )
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Revenue</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>2787.97</td>
#     </tr>
#     <tr>
#       <th>Star Wars: The Force Awakens</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#       <td>2068.22</td>
#     </tr>
#     <tr>
#       <th>Titanic</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>1845.03</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
# ...

# %%
#Hightest Budget
best_worst(n = 5, by = 'Budget')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Pirates of the Caribbean: On Stranger Tides</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//keGfSvCmYj7CvdRx36OdVrAEibE.jpg' style='height:100px;'></td>
#       <td>380.00</td>
#     </tr>
#     <tr>
#       <th>Pirates of the Caribbean: At World's End</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oVh3REsCwJwmrTkZ9OkkeKiAE02.jpg' style='height:100px;'></td>
#       <td>300.00</td>
#     </tr>
#     <tr>
#       <th>Avengers: Age of Ultron</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg' style='height:100px;'></td>
#       <td>280.00</td>
#     </tr>
#     <tr>
#       <th>Superman Returns</th>
# ...

# %%
#Hightest Profit
best_worst(5, 'Profit')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Profit</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>2550.97</td>
#     </tr>
#     <tr>
#       <th>Star Wars: The Force Awakens</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#       <td>1823.22</td>
#     </tr>
#     <tr>
#       <th>Titanic</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>1645.03</td>
#     </tr>
#     <tr>
#       <th>Jurassic World</th>
# ...

# %%
#Lowest Profit
best_worst(5, 'Profit', ascending = True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Profit</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Lone Ranger</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//b2je2ZybNIzAOL1K1WPbbT6zt2M.jpg' style='height:100px;'></td>
#       <td>-165.71</td>
#     </tr>
#     <tr>
#       <th>The Alamo</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//aZrWYkxCCwSPKp4VjVvn46uHbIX.jpg' style='height:100px;'></td>
#       <td>-119.18</td>
#     </tr>
#     <tr>
#       <th>Mars Needs Moms</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lOKqLd0ud1wdwaPK5h6bGNZIVLT.jpg' style='height:100px;'></td>
#       <td>-111.01</td>
#     </tr>
#     <tr>
#       <th>Valerian and the City of a Thousand Planets</th>
# ...

# %%
#Hightest ROI
best_worst(5, 'ROI', min_bud = 0)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Less Than Zero</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//1GY0ZhAxOR2RgxGnOkeKoKb2mFM.jpg' style='height:100px;'></td>
#       <td>12396383.00</td>
#     </tr>
#     <tr>
#       <th>Modern Times</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//7uoiKOEjxBBW0AgDGQWrlfGQ90w.jpg' style='height:100px;'></td>
#       <td>8500000.00</td>
#     </tr>
#     <tr>
#       <th>Welcome to Dongmakgol</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//5iGVw8AdnUJ3xNaZ5iipfsv2e5.jpg' style='height:100px;'></td>
#       <td>4197476.62</td>
#     </tr>
#     <tr>
#       <th>Aquí Entre Nos</th>
# ...

# %%
#Lowest ROI
best_worst(5, 'ROI', ascending = True, min_bud = 50)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Foodfight!</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//R1zn75Yz4wpdd85byqhP7mT6No.jpg' style='height:100px;'></td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Metropolis</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//3F5OKhpC6rqq5KdjgixNbqjWSWz.jpg' style='height:100px;'></td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>Lolita</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//unGWuk8kax8r4PlbGJL9y6WnfFx.jpg' style='height:100px;'></td>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <th>Child 44</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//qqGhMt31HVUN3WnH0L2r0OWq38E.jpg' style='height:100px;'></td>
#       <td>0.07</td>
# ...

# %%
#Most Votes
best_worst(5, 'Votes')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Votes</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Inception</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9gk7adHYeDvHkCSEqAvQNLV5Uge.jpg' style='height:100px;'></td>
#       <td>14075.00</td>
#     </tr>
#     <tr>
#       <th>The Dark Knight</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//qJ2tW6WMUDux911r6m7haRef0WH.jpg' style='height:100px;'></td>
#       <td>12269.00</td>
#     </tr>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>12114.00</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//RYMX2wcKCBAr24UyPD7xwmjaTn.jpg' style='height:100px;'></td>
# ...

# %%
#Hightest Rating
best_worst(5, 'Average Rating', min_votes = 10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Dilwale Dulhania Le Jayenge</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2CAL2433ZeIihfX1Hb2139CX0pW.jpg' style='height:100px;'></td>
#       <td>9.10</td>
#     </tr>
#     <tr>
#       <th>Stop Making Sense</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//uFMsMsk1NGo0QWs9IHknZVHSe4O.jpg' style='height:100px;'></td>
#       <td>8.70</td>
#     </tr>
#     <tr>
#       <th>Human</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//vdZgH8cr73DJTLwvyzFpmm9l3xV.jpg' style='height:100px;'></td>
#       <td>8.60</td>
#     </tr>
#     <tr>
#       <th>Tosun Pasha</th>
# ...

# %%
#Lowest Rating
best_worst(5, 'Average Rating', ascending = True, min_votes = 10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Call Me by Your Name</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tcNniniS4rfqrLH0oORikJfnIwY.jpg' style='height:100px;'></td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Extinction: Nature Has Evolved</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//13LTZkxrAkswx2eidHK06XbVH8n.jpg' style='height:100px;'></td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>The Cloth</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//O0Zh3SIeAonwDoC6cQF8En0inl.jpg' style='height:100px;'></td>
#       <td>1.90</td>
#     </tr>
#     <tr>
#       <th>Manos: The Hands of Fate</th>
# ...

# %%
#Most Popular
best_worst(5, 'Popularity')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Popularity</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Minions</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tMaGZ2HR8HAFwkx4YRib0CDVfNT.jpg' style='height:100px;'></td>
#       <td>547.49</td>
#     </tr>
#     <tr>
#       <th>Wonder Woman</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//gfJGlDaHuWimErCr5Ql0I8x9QSy.jpg' style='height:100px;'></td>
#       <td>294.34</td>
#     </tr>
#     <tr>
#       <th>Beauty and the Beast</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tWqifoYuwLETmmasnGHO7xBjEtt.jpg' style='height:100px;'></td>
#       <td>287.25</td>
#     </tr>
#     <tr>
#       <th>Baby Driver</th>
# ...

# %% [markdown]
# ## Find your next Movie

# %% [markdown]
# 3. __Filter__ the Dataset for movies that meet the following conditions:

# %% [markdown]
# __Search 1: Science Fiction Action Movie with Bruce Willis (sorted from high to low Rating)__

# %%
#Working with a copy of the original dataset
df_next = df.copy()
#Accion and Science Fiction
mask_genres = df.genres.str.contains('Action') & df.genres.str.contains('Science Fiction')
#Bruce Willis condition
mask_actor = df.cast.str.contains('Bruce Willis')

# %%
df_next[mask_genres& mask_actor].sort_values(by = 'vote_average', ascending = False).head(5)
#Another option
df_next.loc[mask_genres & mask_actor, ['title', 'vote_average']].sort_values(by = 'vote_average', ascending = False).head()
# Out:
#                        title  vote_average
# 1448       The Fifth Element          7.30
# 19218                 Looper          6.60
# 1786              Armageddon          6.50
# 14135             Surrogates          5.90
# 20333  G.I. Joe: Retaliation          5.40

# %%
bruce = df.loc[mask_genres & mask_actor, ['title', 'poster_path', 'vote_average']].sort_values(by = 'vote_average',
                                                                                              ascending = False).head().set_index('title')
HTML(bruce.to_html(escape = False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>vote_average</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Fifth Element</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//fPtlCO1yQtnoLHOwKtWz7db6RGU.jpg' style='height:100px;'></td>
#       <td>7.30</td>
#     </tr>
#     <tr>
#       <th>Looper</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//sNjL6SqErDBE8OUZlrDLkexfsCj.jpg' style='height:100px;'></td>
#       <td>6.60</td>
#     </tr>
#     <tr>
#       <th>Armageddon</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//fMtOCd0EAdAzKtGLQiHjSUvbdNc.jpg' style='height:100px;'></td>
#       <td>6.50</td>
#     </tr>
#     <tr>
#       <th>Surrogates</th>
# ...

# %% [markdown]
# __Search 2: Movies with Uma Thurman and directed by Quentin Tarantino (sorted from short to long runtime)__

# %%
#Sorted by short to long feet =)
mask_uma = df.cast.str.contains('Uma Thurman')
mask_directed = df.director.str.contains('Quentin Tarantino')

df.loc[mask_uma & mask_directed,['title', 'cast', 'director', 'runtime']].sort_values(by = 'runtime', ascending = True)
uma = df.loc[mask_uma & mask_directed, ['title', 'poster_path', 'runtime']].sort_values(by = 'runtime', ascending = True).set_index('title')
HTML(uma.to_html(escape = False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>runtime</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Kill Bill: Vol. 1</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//v7TaX8kXMXs5yFFGR41guUDNcnB.jpg' style='height:100px;'></td>
#       <td>111.00</td>
#     </tr>
#     <tr>
#       <th>Kill Bill: Vol. 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2yhg0mZQMhDyvUQ4rG1IZ4oIA8L.jpg' style='height:100px;'></td>
#       <td>136.00</td>
#     </tr>
#     <tr>
#       <th>Pulp Fiction</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//d5iIlFn5s0ImszYzBPb8JPIfbXD.jpg' style='height:100px;'></td>
#       <td>154.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Search 3: Most Successful Pixar Studio Movies between 2010 and 2015 (sorted from high to low Revenue)__

# %%
mask_pixar = df.production_companies.str.contains('Pixar').fillna(False)
mask_year = df.release_date.between('2010-01-01', '2015-12-31')
pixar = df.loc[mask_pixar & mask_year, ['title','poster_path' ,'revenue_musd']].sort_values(by = 'revenue_musd', ascending = False).set_index('title')
HTML(pixar.to_html(escape = False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>revenue_musd</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Toy Story 3</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//amY0NH1ksd9xJ9boXAMmods6U0D.jpg' style='height:100px;'></td>
#       <td>1066.97</td>
#     </tr>
#     <tr>
#       <th>Inside Out</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lRHE0vzf3oYJrhbsHXjIkF4Tl5A.jpg' style='height:100px;'></td>
#       <td>857.61</td>
#     </tr>
#     <tr>
#       <th>Monsters University</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tyHHjZEzJutWggujN1KP0a1jfLX.jpg' style='height:100px;'></td>
#       <td>743.56</td>
#     </tr>
#     <tr>
#       <th>Cars 2</th>
# ...

# %% [markdown]
# __Search 4: Action or Thriller Movie with original language English and minimum Rating of 7.5 (most recent movies first)__

# %%
mask_genre = df.genres.str.contains('Action') | df.genres.str.contains('Thriller')

# %%
mask_language = df.original_language == 'en'

# %%
mask_rating = df[df['vote_average']>=7.5]

# %%
mask_vote  = df.vote_count >= 10

# %%
#This is working but takes so long.
#movies = df.loc[mask_genre & mask_language & mask_rating & mask_vote, ['title', 'poster_path','vote_average',
#        'release_date']].sort_values(by = 'release_date', ascending = False).set_index('title').head(20)

# %% [markdown]
# ## Are Franchises more successful?

# %% [markdown]
# 4. __Analyze__ the Dataset and __find out whether Franchises (Movies that belong to a collection) are more successful than stand-alone movies__ in terms of:

# %% [markdown]
# - mean revenue
# - median Return on Investment
# - mean budget raised
# - mean popularity
# - mean rating

# %%
df.belongs_to_collection
# Out:
# 0                  Toy Story Collection
# 1                                   NaN
# 2             Grumpy Old Men Collection
# 3                                   NaN
# 4        Father of the Bride Collection
#                       ...
# 44686                               NaN
# 44687                               NaN
# 44688                               NaN
# 44689                               NaN
# 44690                               NaN
# Name: belongs_to_collection, Length: 44691, dtype: object

# %%
df['Franchise'] = df.belongs_to_collection.notna()

# %%
df.Franchise
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690    False
# Name: Franchise, Length: 44691, dtype: bool

# %%
df.Franchise.value_counts()
# Out:
# False    40228
# True      4463
# Name: Franchise, dtype: int64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Revenue__

# %%
df.groupby('Franchise').revenue_musd.mean()
# Out:
# Franchise
# False    44.74
# True    165.71
# Name: revenue_musd, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Return on Investment / Profitability (median)__

# %%
df['ROI'] = df.revenue_musd.div(df.budget_musd)

# %%
df.groupby('Franchise').ROI.median()
# Out:
# Franchise
# False   1.62
# True    3.71
# Name: ROI, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Budget__

# %%
df.groupby('Franchise').budget_musd.mean()
# Out:
# Franchise
# False   18.05
# True    38.32
# Name: budget_musd, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Popularity__

# %%
df.groupby('Franchise').popularity.mean()
# Out:
# Franchise
# False   2.59
# True    6.25
# Name: popularity, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Rating__

# %%
df.groupby('Franchise').vote_average.mean()
# Out:
# Franchise
# False   6.01
# True    5.96
# Name: vote_average, dtype: float64

# %%
df.groupby('Franchise').agg({'budget_musd':'mean', 'revenue_musd':'mean', 'vote_average':'mean',
                            'popularity':'mean', 'ROI':'median', 'vote_count':'mean'})
# Out:
#            budget_musd  revenue_musd  vote_average  popularity  ROI  \
# Franchise
# False            18.05         44.74          6.01        2.59 1.62
# True             38.32        165.71          5.96        6.25 3.71
#
#            vote_count
# Franchise
# False           78.29
# True           412.39

# %% [markdown]
# ## Most Successful Franchises

# %% [markdown]
# 5. __Find__ the __most successful Franchises__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total & mean budget__
# - __total & mean revenue__
# - __mean rating__

# %%
df.belongs_to_collection.value_counts()
# Out:
# The Bowery Boys                   29
# Totò Collection                   27
# Zatôichi: The Blind Swordsman     26
# James Bond Collection             26
# The Carry On Collection           25
#                                   ..
# God of Gamblers Collection         1
# Joséphine - Saga                   1
# Spirits' Homecoming Collection     1
# Regalo di Natale - Collezione      1
# Krummerne (Samling)                1
# Name: belongs_to_collection, Length: 1691, dtype: int64

# %%
franchises = df.groupby('belongs_to_collection').agg({'title':'count', 'budget_musd':['sum', 'mean'],
                                                     'revenue_musd':['sum', 'mean'], 
                                                     'vote_average':'mean',
                                                     'popularity':'mean',
                                                     'ROI':'median',
                                                     'vote_count':'mean'})

# %%
franchises
# Out:
#                                      title budget_musd       revenue_musd  \
#                                      count         sum  mean          sum
# belongs_to_collection
# ... Has Fallen Collection                2      130.00 65.00       366.78
# 00 Schneider Filmreihe                   1        0.00   NaN         0.00
# 08/15 Collection                         1        0.00   NaN         0.00
# 100 Girls Collection                     2        0.00   NaN         0.00
# 101 Dalmatians (Animated) Collection     2        4.00  4.00       215.88
# ...                                    ...         ...   ...          ...
# Сказки Чуковского                        1        0.00   NaN         0.00
# Чебурашка и крокодил Гена                1        0.00   NaN         0.00
# Что Творят мужчины! (Коллекция)          2        2.00  2.00         0.00
# 男はつらいよ シリーズ                              3        0.00   NaN         0.00
# ...

# %%
#By titles count
franchises.nlargest(20, ('title', 'count'))
# Out:
#                                        title budget_musd       revenue_musd  \
#                                        count         sum  mean          sum
# belongs_to_collection
# The Bowery Boys                           29        0.00   NaN         0.00
# Totò Collection                           27        0.00   NaN         0.00
# James Bond Collection                     26     1539.65 59.22      7106.97
# Zatôichi: The Blind Swordsman             26        0.00   NaN         0.00
# The Carry On Collection                   25        0.00   NaN         0.00
# Charlie Chan (Sidney Toler) Collection    21        0.00   NaN         0.00
# Pokémon Collection                        20      250.72 50.14       601.87
# Godzilla (Showa) Collection               16        2.81  0.56         0.00
# Charlie Chan (Warner Oland) Collection    15        0.00   NaN         0.00
# Dragon Ball Z (Movie) Collection          15        5.00  5.00       112.12
# ...

# %%
#By revenue
franchises.nlargest(20, ('revenue_musd', 'sum'))
# Out:
#                                     title budget_musd        revenue_musd  \
#                                     count         sum   mean          sum
# belongs_to_collection
# Harry Potter Collection                 8     1280.00 160.00      7707.37
# Star Wars Collection                    8      854.35 106.79      7434.49
# James Bond Collection                  26     1539.65  59.22      7106.97
# The Fast and the Furious Collection     8     1009.00 126.12      5125.10
# Pirates of the Caribbean Collection     5     1250.00 250.00      4521.58
# Transformers Collection                 5      965.00 193.00      4366.10
# Despicable Me Collection                6      299.00  74.75      3691.07
# The Twilight Collection                 5      385.00  77.00      3342.11
# Ice Age Collection                      5      429.00  85.80      3216.71
# Jurassic Park Collection                4      379.00  94.75      3031.48
# ...

# %%
#By revenue
franchises.nlargest(20, ('revenue_musd', 'mean'))
# Out:
#                                     title budget_musd        revenue_musd  \
#                                     count         sum   mean          sum
# belongs_to_collection
# Avatar Collection                       1      237.00 237.00      2787.97
# The Avengers Collection                 2      500.00 250.00      2924.96
# Frozen Collection                       2      150.00 150.00      1274.22
# Finding Nemo Collection                 2      294.00 147.00      1968.91
# The Hobbit Collection                   3      750.00 250.00      2935.52
# The Lord of the Rings Collection        3      266.00  88.67      2916.54
# Harry Potter Collection                 8     1280.00 160.00      7707.37
# Star Wars Collection                    8      854.35 106.79      7434.49
# Despicable Me Collection                6      299.00  74.75      3691.07
# Pirates of the Caribbean Collection     5     1250.00 250.00      4521.58
# ...

# %%
# by budget
franchises.nlargest(20, ('budget_musd', 'sum'))
# Out:
#                                         title budget_musd        revenue_musd  \
#                                         count         sum   mean          sum
# belongs_to_collection
# James Bond Collection                      26     1539.65  59.22      7106.97
# Harry Potter Collection                     8     1280.00 160.00      7707.37
# Pirates of the Caribbean Collection         5     1250.00 250.00      4521.58
# The Fast and the Furious Collection         8     1009.00 126.12      5125.10
# X-Men Collection                            6      983.00 163.83      2808.83
# Transformers Collection                     5      965.00 193.00      4366.10
# Star Wars Collection                        8      854.35 106.79      7434.49
# The Hobbit Collection                       3      750.00 250.00      2935.52
# The Terminator Collection                   5      661.40 132.28      1845.33
# Mission: Impossible Collection              5      650.00 130.00      2778.98
# ...

# %%
#by rates
franchises[franchises[('vote_count', 'mean')]>=1000].nlargest(20, ('vote_average', 'mean'))
# Out:
#                                     title budget_musd        revenue_musd  \
#                                     count         sum   mean          sum
# belongs_to_collection
# The Lord of the Rings Collection        3      266.00  88.67      2916.54
# The Godfather Collection                3       73.00  24.33       429.38
# Blade Runner Collection                 1       28.00  28.00        33.14
# The Man With No Name Collection         3        2.00   0.67        35.50
# The Dark Knight Collection              3      585.00 195.00      2463.72
# Guardians of the Galaxy Collection      2      370.00 185.00      1636.74
# Kill Bill Collection                    2       60.00  30.00       333.11
# Kingsman Collection                     1       81.00  81.00       414.35
# How to Train Your Dragon Collection     2      310.00 155.00      1104.00
# Harry Potter Collection                 8     1280.00 160.00      7707.37
# ...

# %% [markdown]
# ## Most Successful Directors

# %% [markdown]
# 6. __Find__ the __most successful Directors__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total revenue__
# - __mean rating__

# %%
#Graphic
plt.figure(figsize = (12,8))
df.director.value_counts().head(20).plot(kind = 'bar', fontsize = 15)
plt.title('Most Active Directors', fontsize = 20)
plt.ylabel('Number of Movies', fontsize = 15)
plt.show()

# %%
director = df.groupby('director').agg({'title':'count', 'revenue_musd':'sum', 'vote_count':'mean'})

# %%
director.nlargest(20, ('title'))
# Out:
#                     title  revenue_musd  vote_count
# director
# John Ford              66         85.17       33.48
# Michael Curtiz         65         37.82       38.09
# Werner Herzog          54         24.57       46.59
# Alfred Hitchcock       53        250.11      240.98
# Georges Méliès         49          0.00       16.86
# Woody Allen            49        993.97      316.57
# Jean-Luc Godard        46          0.87       32.13
# Sidney Lumet           46        294.52      114.93
# Charlie Chaplin        44         26.52       85.18
# Raoul Walsh            43          1.21       13.56
# William A. Wellman     42          0.00       12.48
# Henry Hathaway         41         24.95       17.76
# Richard Thorpe         40          0.00        6.85
# Ingmar Bergman         39         11.50       66.69
# Martin Scorsese        39       1990.98      911.31
# Fritz Lang             38          3.60       51.87
# George Cukor           38         74.34       30.13
# ...

# %%
#By Revenue
director.nlargest(20, ('revenue_musd'))
# Out:
#                    title  revenue_musd  vote_count
# director
# Steven Spielberg      33       9256.62     1886.85
# Peter Jackson         13       6528.24     3659.31
# Michael Bay           13       6437.47     2212.85
# James Cameron         11       5900.61     3066.91
# David Yates            9       5334.56     3450.67
# Christopher Nolan     11       4747.41     6122.18
# Robert Zemeckis       19       4138.23     1982.42
# Tim Burton            21       4032.92     1758.19
# Ridley Scott          24       3917.53     1795.12
# Chris Columbus        15       3866.84     1760.87
# Roland Emmerich       16       3798.40     1255.31
# Ron Howard            26       3714.15      820.96
# J.J. Abrams            5       3579.22     4320.80
# Gore Verbinski        10       3575.34     2535.40
# George Lucas           7       3341.55     2884.29
# Sam Raimi             15       3193.79     1463.73
# Francis Lawrence       6       3183.34     4038.83
# ...

# %%
#Graphic
plt.figure(figsize = (12,8))
director.nlargest(20, ('revenue_musd'))['revenue_musd'].plot(kind = 'bar', fontsize = 15)
plt.title('Total Revenue', fontsize = 20)
plt.ylabel('Revenue(in MUSD)', fontsize = 15)
plt.show()

# %%
#by rating
director.nlargest(20, 'vote_count')
# Out:
#                    title  revenue_musd  vote_count
# director
# Tim Miller             1        783.11    11444.00
# Christopher Nolan     11       4747.41     6122.18
# Pierre Coffin          2       1514.28     5662.00
# Pete Docter            4       2155.53     5019.00
# Alex Garland           1         36.87     4862.00
# Andrew Stanton         4       2774.36     4808.50
# Lee Unkrich            1       1066.97     4710.00
# Rich Moore             1        471.22     4656.00
# Lana Wachowski         2        470.53     4641.00
# Robert Stromberg       1        758.54     4607.00
# Quentin Tarantino     10       1526.67     4591.00
# Wes Ball               2        659.58     4344.00
# J.J. Abrams            5       3579.22     4320.80
# Chad Stahelski         2        260.30     4211.50
# Joss Whedon            5       2963.83     4109.60
# Shane Black            3       1294.01     4077.67
# Chris Williams         2        962.09     4043.50
# ...

# %%
#Graphic
plt.figure(figsize = (20,10))
director.nlargest(20, 'vote_count')['vote_count'].plot(kind = 'bar', fontsize = 15)
plt.title('Mean of Count Votes', fontsize = 20)
plt.ylabel('Count Votes( mean)', fontsize = 15)
plt.show()

# %%
#By Genre
df.genres = df.genres.astype(str)

# %%
df.loc[df.genres.str.contains('Horror')].groupby('director').revenue_musd.sum().nlargest(20)
# Out:
# director
# Paul W.S. Anderson    982.29
# James Wan             861.31
# Wes Craven            834.93
# Francis Lawrence      816.23
# Ridley Scott          689.00
# Marc Forster          531.87
# Steven Spielberg      500.10
# William Friedkin      466.40
# Darren Lynn Bousman   456.34
# M. Night Shyamalan    375.37
# Henry Joost           349.07
# David R. Ellis        348.74
# Adrian Lyne           346.11
# James DeMonaco        316.70
# Stephen Sommers       311.46
# Gore Verbinski        275.91
# Guillermo del Toro    261.63
# John R. Leonetti      255.27
# Fede Alvarez          254.64
# Jordan Peele          252.43
# Name: revenue_musd, dtype: float64

# %% [markdown]
# # Most Succesful Actors

# %%
df.cast
# Out:
# 0        Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...
# 1        Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...
# 2        Walter Matthau|Jack Lemmon|Ann-Margret|Sophia ...
# 3        Whitney Houston|Angela Bassett|Loretta Devine|...
# 4        Steve Martin|Diane Keaton|Martin Short|Kimberl...
#                                ...
# 44686              Leila Hatami|Kourosh Tahami|Elham Korda
# 44687    Angel Aquino|Perry Dizon|Hazel Orencio|Joel To...
# 44688    Erika Eleniak|Adam Baldwin|Julie du Page|James...
# 44689    Iwan Mosschuchin|Nathalie Lissenko|Pavel Pavlo...
# 44690                                                  NaN
# Name: cast, Length: 44691, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   tagline                20284 non-null  object
#  3   release_date           44657 non-null  datetime64[ns]
#  4   genres                 44691 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44681 non-null  object
#  7   budget_musd            8854 non-null   float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38835 non-null  object
#  11  vote_count             44691 non-null  float64
#  12  vote_average           42077 non-null  float64
#  13  popularity             44691 non-null  float64
# ...

# %%
#Split actors
df.cast.str.split('|')
# Out:
# 0        [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...
# 1        [Robin Williams, Jonathan Hyde, Kirsten Dunst,...
# 2        [Walter Matthau, Jack Lemmon, Ann-Margret, Sop...
# 3        [Whitney Houston, Angela Bassett, Loretta Devi...
# 4        [Steve Martin, Diane Keaton, Martin Short, Kim...
#                                ...
# 44686          [Leila Hatami, Kourosh Tahami, Elham Korda]
# 44687    [Angel Aquino, Perry Dizon, Hazel Orencio, Joe...
# 44688    [Erika Eleniak, Adam Baldwin, Julie du Page, J...
# 44689    [Iwan Mosschuchin, Nathalie Lissenko, Pavel Pa...
# 44690                                                  NaN
# Name: cast, Length: 44691, dtype: object

# %%
act = df.cast.str.split('|', expand = True)

# %%
act
# Out:
#                     0                  1               2    \
# 0             Tom Hanks          Tim Allen     Don Rickles
# 1        Robin Williams      Jonathan Hyde   Kirsten Dunst
# 2        Walter Matthau        Jack Lemmon     Ann-Margret
# 3       Whitney Houston     Angela Bassett  Loretta Devine
# 4          Steve Martin       Diane Keaton    Martin Short
# ...                 ...                ...             ...
# 44686      Leila Hatami     Kourosh Tahami     Elham Korda
# 44687      Angel Aquino        Perry Dizon   Hazel Orencio
# 44688     Erika Eleniak       Adam Baldwin   Julie du Page
# 44689  Iwan Mosschuchin  Nathalie Lissenko    Pavel Pavlov
# 44690               NaN                NaN             NaN
#
#                              3               4                  5    \
# 0                     Jim Varney   Wallace Shawn  John Ratzenberger
# 1                 Bradley Pierce     Bonnie Hunt      Bebe Neuwirth
# ...

# %%
act.stack()
# Out:
# 0      0            Tom Hanks
#        1            Tim Allen
#        2          Don Rickles
#        3           Jim Varney
#        4        Wallace Shawn
#                   ...
# 44689  0     Iwan Mosschuchin
#        1    Nathalie Lissenko
#        2         Pavel Pavlov
#        3    Aleksandr Chabrov
#        4          Vera Orlova
# Length: 557703, dtype: object

# %%
act.stack().reset_index(level = 1, drop = True).to_frame()
# Out:
#                        0
# 0              Tom Hanks
# 0              Tim Allen
# 0            Don Rickles
# 0             Jim Varney
# 0          Wallace Shawn
# ...                  ...
# 44689   Iwan Mosschuchin
# 44689  Nathalie Lissenko
# 44689       Pavel Pavlov
# 44689  Aleksandr Chabrov
# 44689        Vera Orlova
#
# [557703 rows x 1 columns]

# %%
act = act.stack().reset_index(level = 1, drop = True).to_frame()

# %%
act
# Out:
#                        0
# 0              Tom Hanks
# 0              Tim Allen
# 0            Don Rickles
# 0             Jim Varney
# 0          Wallace Shawn
# ...                  ...
# 44689   Iwan Mosschuchin
# 44689  Nathalie Lissenko
# 44689       Pavel Pavlov
# 44689  Aleksandr Chabrov
# 44689        Vera Orlova
#
# [557703 rows x 1 columns]

# %%
act.columns = ['Actor']

# %%
act = act.merge(df[['title', 'revenue_musd', 'vote_average', 'popularity']], 
               how = 'left', left_index = True,right_index = True)

# %%
act
# Out:
#                    Actor             title  revenue_musd  vote_average  \
# 0              Tom Hanks         Toy Story        373.55          7.70
# 0              Tim Allen         Toy Story        373.55          7.70
# 0            Don Rickles         Toy Story        373.55          7.70
# 0             Jim Varney         Toy Story        373.55          7.70
# 0          Wallace Shawn         Toy Story        373.55          7.70
# ...                  ...               ...           ...           ...
# 44689   Iwan Mosschuchin  Satan Triumphant           NaN           NaN
# 44689  Nathalie Lissenko  Satan Triumphant           NaN           NaN
# 44689       Pavel Pavlov  Satan Triumphant           NaN           NaN
# 44689  Aleksandr Chabrov  Satan Triumphant           NaN           NaN
# 44689        Vera Orlova  Satan Triumphant           NaN           NaN
#
#        popularity
# 0           21.95
# 0           21.95
# 0           21.95
# 0           21.95
# ...

# %%
act.Actor.nunique()
# Out:
# 201501

# %%
act.Actor.unique()
# Out:
# array(['Tom Hanks', 'Tim Allen', 'Don Rickles', ..., 'Kiko Ellsworth',
#        'Darrell Dubovsky', 'Aleksandr Chabrov'], dtype=object)

# %%
act.Actor.value_counts().head(20)
# Out:
# Bess Flowers          240
# Christopher Lee       148
# John Wayne            125
# Samuel L. Jackson     122
# Michael Caine         110
# Gérard Depardieu      109
# John Carradine        109
# Donald Sutherland     108
# Jackie Chan           108
# Frank Welker          107
# Robert De Niro        104
# Steve Buscemi         101
# Danny Trejo           101
# Irving Bacon           98
# John Goodman           97
# Christopher Walken     96
# Danny Glover           95
# John Hurt              93
# Dennis Hopper          92
# Susan Sarandon         92
# Name: Actor, dtype: int64

# %%
plt.figure(figsize = (12,8))
act.Actor.value_counts().head(20).plot(kind = 'bar', fontsize = 15)
plt.title('Most Active Actors', fontsize = 15)
plt.ylabel('Number of Movies', fontsize = 15)
plt.show()

# %%
agg = act.groupby('Actor').agg(Total_Revenue = ('revenue_musd', 'sum'),
                              Mean_Revenue = ('revenue_musd', 'mean'),
                              Mean_Rating = ('vote_average', 'mean'),
                              Mean_Pop = ('popularity', 'mean'),
                              Total_Movies = ('Actor', 'count'))

# %%
agg.nlargest(10, 'Total_Movies')
# Out:
#                    Total_Revenue  Mean_Revenue  Mean_Rating  Mean_Pop  \
# Actor
# Bess Flowers              368.91         14.76         6.18      2.03
# Christopher Lee          9417.05        324.73         5.91      4.75
# John Wayne                236.09         11.24         5.71      3.09
# Samuel L. Jackson       17109.62        213.87         6.27     11.70
# Michael Caine            8053.40        191.75         6.27      8.27
# Gérard Depardieu         1247.61         95.97         6.05      3.70
# John Carradine            255.84         19.68         5.55      2.43
# Donald Sutherland        5390.77        138.22         6.23      7.00
# Jackie Chan              4699.19        146.85         6.28      5.86
# Frank Welker            13044.15        326.10         6.31      9.57
#
#                    Total_Movies
# Actor
# Bess Flowers                240
# Christopher Lee             148
# John Wayne                  125
# Samuel L. Jackson           122
# ...

# %%
agg.nlargest(10, 'Total_Revenue')
# Out:
#                    Total_Revenue  Mean_Revenue  Mean_Rating  Mean_Pop  \
# Actor
# Stan Lee                19414.96        647.17         6.51     29.94
# Samuel L. Jackson       17109.62        213.87         6.27     11.70
# Warwick Davis           13256.03        662.80         6.29     13.09
# Frank Welker            13044.15        326.10         6.31      9.57
# John Ratzenberger       12596.13        449.86         6.48     10.96
# Jess Harnell            12234.61        611.73         6.44     10.92
# Hugo Weaving            11027.58        459.48         6.47     10.97
# Ian McKellen            11015.59        478.94         6.35     15.45
# Johnny Depp             10653.76        217.42         6.44     12.38
# Alan Rickman            10612.63        353.75         6.72     10.40
#
#                    Total_Movies
# Actor
# Stan Lee                     48
# Samuel L. Jackson           122
# Warwick Davis                34
# Frank Welker                107
# ...

# %%
plt.figure(figsize = (20,10))
agg.Total_Movies.nlargest(10).plot(kind = 'bar', fontsize = 15)
plt.title('Total Revenue', fontsize = 15)
plt.ylabel('Revenue(in MUSD)', fontsize = 15)
plt.show()

# %%
agg.Mean_Revenue.nlargest(10)
# Out:
# Actor
# April Marie Thomas   2787.97
# Ashley Jeffery       2787.97
# Austin Wilson        2787.97
# Brandon Jelkes       2787.97
# Bravita A. Threatt   2787.97
# Carvon Futrell       2787.97
# Chris Mala           2787.97
# Christa Oliver       2787.97
# Christopher Nolen    2787.97
# Colin Bleasdale      2787.97
# Name: Mean_Revenue, dtype: float64

# %%
act[act.Actor =='Ashley Jeffery']
# Out:
#                 Actor   title  revenue_musd  vote_average  popularity
# 14448  Ashley Jeffery  Avatar       2787.97          7.20      185.07

# %%
agg[agg.Total_Movies >=10].nlargest(10, 'Mean_Revenue')
# Out:
#                   Total_Revenue  Mean_Revenue  Mean_Rating  Mean_Pop  \
# Actor
# Gloria Stuart           1845.03       1845.03         6.37      3.48
# Keith Richards          2967.71        989.24         6.46      5.03
# Zoë Wanamaker            976.48        976.48         6.33      6.82
# James Cameron           1862.08        931.04         7.06      4.69
# Matthew Lewis           7915.31        879.48         7.37     23.10
# Luke de Woolfson        1720.67        860.34         5.72      8.77
# Yuri Lowenthal          1708.16        854.08         6.19     19.88
# Dominic Monaghan        3289.61        822.40         6.05     10.62
# Philip Ng                821.71        821.71         5.92      6.35
# Peter Mayhew            4820.72        803.45         6.70     12.30
#
#                   Total_Movies
# Actor
# Gloria Stuart               18
# Keith Richards              23
# Zoë Wanamaker               10
# James Cameron               12
# Matthew Lewis               11
# ...

# %%
agg[agg.Total_Movies >=10].nlargest(10, 'Mean_Rating')
# Out:
#                     Total_Revenue  Mean_Revenue  Mean_Rating  Mean_Pop  \
# Actor
# Masao Hayama                 0.00           NaN         8.84      0.32
# David Attenborough           0.00           NaN         8.27      2.15
# Halit Akçatepe               0.21          0.21         7.78      0.74
# Emil Jannings                0.00           NaN         7.78      1.70
# Yo Oizumi                  511.21        102.24         7.72      7.51
# Şener Şen                   11.07          3.69         7.69      0.91
# Ayşen Gruda                  0.91          0.46         7.68      0.74
# Akira Tani                   0.33          0.16         7.65      5.04
# Joseph Oliveira           3543.44        354.34         7.64     34.45
# Björk                       51.33         25.67         7.62      2.36
#
#                     Total_Movies
# Actor
# Masao Hayama                  10
# David Attenborough            11
# Halit Akçatepe                10
# Emil Jannings                 10
# ...

# %%
agg[agg.Total_Movies >=10].nlargest(10, 'Mean_Pop')
# Out:
#                  Total_Revenue  Mean_Revenue  Mean_Rating  Mean_Pop  \
# Actor
# Katy Mixon             1519.57        151.96         5.84     51.97
# Terry Notary           6947.21        694.72         6.47     51.58
# Goran D. Kleut         2568.94        366.99         6.00     42.32
# Mark Smith             2195.52        243.95         6.55     40.08
# Jon Hamm               3449.35        191.63         6.33     39.42
# Gal Gadot              5449.53        495.41         6.33     37.39
# Ava Acres              6272.36        482.49         5.99     36.26
# Emma Watson            9639.20        535.51         6.77     35.97
# Joseph Oliveira        3543.44        354.34         7.64     34.45
# Keith Jardine          1062.49        212.50         5.96     32.00
#
#                  Total_Movies
# Actor
# Katy Mixon                 12
# Terry Notary               11
# Goran D. Kleut             10
# Mark Smith                 11
# Jon Hamm                   25
# ...

# %% [markdown]
# # What are the most common Words in Movie Titles and Taglines?

# %%
from wordcloud import WordCloud

# %%
df.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                      genres           belongs_to_collection original_language  \
# 0   Animation|Comedy|Family            Toy Story Collection                en
# 1  Adventure|Fantasy|Family                             NaN                en
# 2            Romance|Comedy       Grumpy Old Men Collection                en
# ...

# %%
df.tagline[1]
# Out:
# 'Roll the dice and unleash the excitement!'

# %%
df.overview[1]
# Out:
# "When siblings Judy and Peter discover an enchanted board game that opens the door to a magical world, they unwittingly invite Alan -- an adult who's been trapped inside the game for 26 years -- into their living room. Alan's only hope for freedom is to finish the game, which proves risky as all three find themselves running from giant rhinoceroses, evil monkeys and other terrifying creatures."

# %%
title = df.title.dropna()

# %%
overview = df.overview.dropna()

# %%
tagline = df.tagline.dropna()

# %%
#Join
title_corpus = ' '.join(title)
overview_corpus = ' '.join(overview)
tagline_corpus = ' '.join(tagline)

# %%
title_wordcloud = WordCloud(background_color = 'white', height = 2000, width = 4000, max_words = 200).generate(title_corpus)
title_wordcloud

# %%
plt.figure(figsize = (16,8))
plt.imshow(title_wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %%
overview_wordcloud = WordCloud(background_color = 'white', height = 2000, width = 4000, max_words = 200).generate(overview_corpus)
overview_wordcloud

# %%
plt.figure(figsize = (16,8))
plt.imshow(overview_wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %%
tagline_wordcloud = WordCloud(background_color = 'white', height = 2000, width = 4000, max_words = 200).generate(tagline_corpus)
tagline_wordcloud

# %%
plt.figure(figsize = (16,8))
plt.imshow(tagline_wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# # What are the most successful/popular genres? Has this changed over time (e.g. 80ths vs. 90ths)?

# %%
year_1980s = df.release_date.between('1980-01-01', '1989-12-31')
year_1990s = df.release_date.between('1990-01-01', '1999-12-31')

# %%
data_1980 = df[year_1980s].genres.str.split('|', expand = True)

# %%
data_1980 = data_1980.stack().reset_index(level = 1, drop = True).to_frame()

# %%
data_1980.columns = ['genre']

# %%
data_1980
# Out:
#                  genre
# 535    Science Fiction
# 535              Drama
# 535           Thriller
# 539            History
# 539              Drama
# ...                ...
# 44651          Fantasy
# 44651           Comedy
# 44651          Romance
# 44651            Drama
# 44677      Documentary
#
# [8180 rows x 1 columns]

# %%
data_1980= data_1980.merge(df[['title', 'revenue_musd', 'vote_average', 'popularity']], 
               how = 'left', left_index = True,right_index = True)

# %%
data_1980
# Out:
#                  genre                                              title  \
# 535    Science Fiction                                       Blade Runner
# 535              Drama                                       Blade Runner
# 535           Thriller                                       Blade Runner
# 539            History                                              Harem
# 539              Drama                                              Harem
# ...                ...                                                ...
# 44651          Fantasy  A Black Rose Is an Emblem of Sorrow, a Red Ros...
# 44651           Comedy  A Black Rose Is an Emblem of Sorrow, a Red Ros...
# 44651          Romance  A Black Rose Is an Emblem of Sorrow, a Red Ros...
# 44651            Drama  A Black Rose Is an Emblem of Sorrow, a Red Ros...
# 44677      Documentary                                        Deep Hearts
#
#        revenue_musd  vote_average  popularity
# ...

# %%
data_1980.groupby('genre').agg(Cuenta = ('genre','count')).nlargest(5, 'Cuenta')
# Out:
#           Cuenta
# genre
# Drama       1541
# Comedy      1289
# Action       710
# Horror       641
# Thriller     597

# %%
#1990
data_1990 = df[year_1990s].genres.str.split('|', expand = True)

# %%
data_1990 = data_1990.stack().reset_index(level = 1, drop = True).to_frame()

# %%
data_1990.columns = ['genre']

# %%
data_1990
# Out:
#                  genre
# 0            Animation
# 0               Comedy
# 0               Family
# 1            Adventure
# 1              Fantasy
# ...                ...
# 44656  Science Fiction
# 44684  Science Fiction
# 44685            Drama
# 44685           Action
# 44685          Romance
#
# [11944 rows x 1 columns]

# %%
data_1990.groupby('genre').agg(cuenta = ('genre', 'count')).nlargest(5, 'cuenta')
# Out:
#           cuenta
# genre
# Drama       2592
# Comedy      1841
# Thriller    1044
# Action       992
# Romance      982

# %% [markdown]
# # What are the most successful/active production companies?

# %%
df.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                      genres           belongs_to_collection original_language  \
# 0   Animation|Comedy|Family            Toy Story Collection                en
# 1  Adventure|Fantasy|Family                             NaN                en
# 2            Romance|Comedy       Grumpy Old Men Collection                en
# ...

# %%
production_active = df.production_companies.str.split('|', expand = True)

# %%
production_active
# Out:
#                                            0                    1   \
# 0                     Pixar Animation Studios                 None
# 1                            TriStar Pictures         Teitler Film
# 2                                Warner Bros.       Lancaster Gate
# 3      Twentieth Century Fox Film Corporation                 None
# 4                       Sandollar Productions  Touchstone Pictures
# ...                                       ...                  ...
# 44686                                     NaN                  NaN
# 44687                             Sine Olivia                 None
# 44688                 American World Pictures                 None
# 44689                               Yermoliev                 None
# 44690                                     NaN                  NaN
#
#                               2     3     4     5     6     7     8     9   \
# 0                           None  None  None  None  None  None  None  None
# ...

# %%
production_active = production_active.stack().reset_index(level = 1, drop = True).to_frame()

# %%
production_active.columns = ['company']

# %%
production_active =  production_active.merge(df[['title', 'revenue_musd', 'vote_average', 'popularity']], 
               how = 'left', left_index = True,right_index = True)

# %%
#Actividad
production_active.groupby('company').agg(actividad = ('company','count'),
                                        ingresos = ('revenue_musd', 'sum')).nlargest(5, 'actividad')
# Out:
#                                         actividad  ingresos
# company
# Warner Bros.                                 1248  63525.19
# Metro-Goldwyn-Mayer (MGM)                    1073  12376.79
# Paramount Pictures                            996  48769.40
# Twentieth Century Fox Film Corporation        834  47687.75
# Universal Pictures                            827  55259.19

# %%
#Ingresos
production_active.groupby('company').agg(actividad = ('company','count'),
                                        ingresos = ('revenue_musd', 'sum')).nlargest(5, 'ingresos')
# Out:
#                                         actividad  ingresos
# company
# Warner Bros.                                 1248  63525.19
# Universal Pictures                            827  55259.19
# Paramount Pictures                            996  48769.40
# Twentieth Century Fox Film Corporation        834  47687.75
# Walt Disney Pictures                          262  40837.27

# %% [markdown]
# # Get the highest-rated Action movies of the 90ths!

# %%
action = df.genres.str.contains('Action')
year_1990s = df.release_date.between('1990-01-01', '1999-12-31')

# %%
df.loc[action & year_1990s, ['title', 'vote_average']].sort_values(by = 'vote_average', ascending = False).head()
# Out:
#                                    title  vote_average
# 30461  Mortal Kombat: The Journey Begins         10.00
# 27464                                Pan         10.00
# 2920                           Ten Benny         10.00
# 2102                      One Man's Hero          9.30
# 42156                     To Be the Best          9.00
